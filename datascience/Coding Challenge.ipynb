# %%
# %load_ext google.cloud.bigquery

# %% [markdown]
# # "Will it snow tomorrow?" - The time traveler asked
# The following dataset contains climate information form over 9000 stations accross the world. The overall goal of these subtasks will be to predict whether it will snow tomorrow 11 years ago. So if today is 2021.02.15 then the weather we want to forecast is for the date 2010.02.16. You are suppsed to solve the tasks using Big Query, which can be used in the Jupyter Notebook like it is shown in the following cell. For further information and how to used BigQuery in Jupyter Notebook refer to the Google Docs.
#
# The goal of this test is, to test your coding knowledge in Python, BigQuery and Pandas as well as your understanding of Data Science. If you get stuck at the first part, you can use the replacement data provided in the second part

# %%
# %%bigquery
# SELECT
# *,
# DATE(year,month,day) AS date,
# FROM `bigquery-public-data.samples.gsod`
# WHERE station_number =  725300
# ORDER BY date DESC
# LIMIT 20
# Out:
#     station_number  wban_number  year  month  day  mean_temp  \
# 0           725300        94846  2010      4   16  69.599998
# 1           725300        94846  2010      4   15  70.800003
# 2           725300        94846  2010      4   14  61.200001
# 3           725300        94846  2010      4   13  56.099998
# 4           725300        94846  2010      4   12  56.599998
# 5           725300        94846  2010      4   11  55.500000
# 6           725300        94846  2010      4   10  53.299999
# 7           725300        94846  2010      4    9  41.200001
# 8           725300        94846  2010      4    8  38.400002
# 9           725300        94846  2010      4    7  48.099998
# 10          725300        94846  2010      4    6  55.400002
# 11          725300        94846  2010      4    5  58.599998
# 12          725300        94846  2010      4    4  56.799999
# 13          725300        94846  2010      4    3  57.900002
# 14          725300        94846  2010      4    2  70.800003
# 15          725300        94846  2010      4    1  68.199997
# 16          725300        94846  2010      3   31  60.700001
# 17          725300        94846  2010      3   30  43.099998
# 18          725300        94846  2010      3   29  38.799999
# 19          725300        94846  2010      3   28  43.799999
#
#     num_mean_temp_samples  mean_dew_point  num_mean_dew_point_samples  \
# 0                       9       49.000000                           9
# 1                      24       44.700001                          24
# 2                      24       43.799999                          24
# 3                      24       36.400002                          24
# 4                      24       31.200001                          24
# 5                      24       37.900002                          24
# 6                      24       34.299999                          24
# 7                      24       27.400000                          24
# 8                      24       34.200001                          24
# 9                      24       45.299999                          24
# 10                     24       47.500000                          24
# 11                     24       48.200001                          24
# 12                     24       39.099998                          24
# 13                     24       45.700001                          24
# 14                     24       47.900002                          24
# 15                     24       48.500000                          24
# 16                     24       41.500000                          24
# 17                     24       31.900000                          24
# 18                     24       29.500000                          24
# 19                     24       28.000000                          24
#
#     mean_sealevel_pressure  ...  min_temperature_explicit  \
# 0              1016.599976  ...                      None
# 1              1022.000000  ...                      None
# 2              1027.199951  ...                      None
# 3              1025.000000  ...                      None
# 4              1027.099976  ...                      None
# 5              1024.500000  ...                      None
# 6              1020.400024  ...                      None
# 7              1015.799988  ...                      None
# 8              1007.000000  ...                      None
# 9              1001.799988  ...                      None
# 10             1003.200012  ...                      None
# 11             1013.500000  ...                      None
# 12             1014.400024  ...                      None
# 13             1007.099976  ...                      None
# 14             1006.099976  ...                      None
# 15             1006.900024  ...                      None
# 16             1007.700012  ...                      None
# 17             1014.799988  ...                      None
# 18             1015.400024  ...                      None
# 19             1009.500000  ...                      None
#
#     total_precipitation  snow_depth    fog   rain   snow   hail  thunder  \
# 0                  0.00         NaN  False  False  False  False    False
# 1                  0.00         NaN  False  False  False  False    False
# 2                  0.00         NaN  False  False  False  False    False
# 3                  0.01         NaN  False  False  False  False    False
# 4                  0.00         NaN  False  False  False  False    False
# 5                  0.00         NaN  False  False  False  False    False
# 6                  0.00         NaN  False  False  False  False    False
# 7                  0.00         NaN  False  False  False  False    False
# 8                  0.08         NaN  False  False  False  False    False
# 9                  0.42         NaN  False  False  False  False    False
# 10                 0.82         NaN  False  False  False  False    False
# 11                 0.80         NaN  False  False  False  False    False
# 12                 0.05         NaN  False  False  False  False    False
# 13                 0.18         NaN  False  False  False  False    False
# 14                 0.00         NaN  False  False  False  False    False
# 15                 0.00         NaN  False  False  False  False    False
# 16                 0.00         NaN  False  False  False  False    False
# 17                 0.00         NaN  False  False  False  False    False
# 18                 0.00         NaN  False  False  False  False    False
# 19                 0.01         NaN  False  False  False  False    False
#
#     tornado        date
# 0     False  2010-04-16
# 1     False  2010-04-15
# 2     False  2010-04-14
# 3     False  2010-04-13
# 4     False  2010-04-12
# 5     False  2010-04-11
# 6     False  2010-04-10
# 7     False  2010-04-09
# 8     False  2010-04-08
# 9     False  2010-04-07
# 10    False  2010-04-06
# 11    False  2010-04-05
# 12    False  2010-04-04
# 13    False  2010-04-03
# 14    False  2010-04-02
# 15    False  2010-04-01
# 16    False  2010-03-31
# 17    False  2010-03-30
# 18    False  2010-03-29
# 19    False  2010-03-28
#
# [20 rows x 32 columns]

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### 1. Task
# Change the date format to 'YYYY-MM-DD' and select the data from 2005 till 2010 for station 725300 and 997338 , and save it as a pandas dataframe. Note the maximum year available is 2010.

# %%
# %%bigquery climate
# SELECT
# * EXCEPT(year,month,day),
# DATE(year,month,day) AS date,
# FROM `bigquery-public-data.samples.gsod`
# WHERE station_number = 725300 AND year > 2005
# OR station_number = 997338 AND year > 2005
# ORDER BY date DESC

# %% [markdown]
# Comments: testing simple logical conditining, knowledge about sql syntax, and ability to find in doc how to store as df variable

# %% [markdown]
# ### 2. Task
# From here on we only want to work with the data from station 725300. Dropt the irrelevant data and save it in a new dataframe.

# %%
climate[climate['station_number'] == 725300]
# Out:
#       station_number  wban_number  mean_temp  num_mean_temp_samples  \
# 0             725300        94846  69.599998                      9
# 1             725300        94846  70.800003                     24
# 4             725300        94846  61.200001                     24
# 6             725300        94846  56.099998                     24
# 7             725300        94846  56.599998                     24
# ...              ...          ...        ...                    ...
# 2714          725300        94846  35.599998                     24
# 2717          725300        94846  41.599998                     24
# 2718          725300        94846  39.500000                     24
# 2721          725300        94846  41.200001                     24
# 2722          725300        94846  35.099998                     24
#
#       mean_dew_point  num_mean_dew_point_samples  mean_sealevel_pressure  \
# 0          49.000000                         9.0             1016.599976
# 1          44.700001                        24.0             1022.000000
# 4          43.799999                        24.0             1027.199951
# 6          36.400002                        24.0             1025.000000
# 7          31.200001                        24.0             1027.099976
# ...              ...                         ...                     ...
# 2714       29.500000                        24.0             1014.400024
# 2717       38.599998                        24.0             1008.200012
# 2718       37.799999                        24.0             1011.099976
# 2721       38.400002                        24.0             1004.200012
# 2722       28.799999                        24.0             1011.200012
#
#       num_mean_sealevel_pressure_samples  mean_station_pressure  \
# 0                                    9.0             992.599976
# 1                                   24.0             997.799988
# 4                                   24.0            1002.500000
# 6                                   24.0            1000.500000
# 7                                   24.0            1002.299988
# ...                                  ...                    ...
# 2714                                22.0                    NaN
# 2717                                17.0                    NaN
# 2718                                22.0                    NaN
# 2721                                18.0                    NaN
# 2722                                23.0                    NaN
#
#       num_mean_station_pressure_samples  ...  min_temperature_explicit  \
# 0                                   9.0  ...                      None
# 1                                  24.0  ...                      None
# 4                                  24.0  ...                      None
# 6                                  24.0  ...                      None
# 7                                  24.0  ...                      None
# ...                                 ...  ...                       ...
# 2714                                NaN  ...                      None
# 2717                                NaN  ...                      None
# 2718                                NaN  ...                      None
# 2721                                NaN  ...                      None
# 2722                                NaN  ...                      None
#
#       total_precipitation  snow_depth    fog   rain   snow   hail  thunder  \
# 0                    0.00         NaN  False  False  False  False    False
# 1                    0.00         NaN  False  False  False  False    False
# 4                    0.00         NaN  False  False  False  False    False
# 6                    0.01         NaN  False  False  False  False    False
# 7                    0.00         NaN  False  False  False  False    False
# ...                   ...         ...    ...    ...    ...    ...      ...
# 2714                 0.02         NaN  False  False  False  False    False
# 2717                 0.00         NaN   True   True   True   True     True
# 2718                 0.36         NaN  False  False  False  False    False
# 2721                 0.04         NaN  False  False  False  False    False
# 2722                 0.00         NaN  False  False  False  False    False
#
#       tornado        date
# 0       False  2010-04-16
# 1       False  2010-04-15
# 4       False  2010-04-14
# 6       False  2010-04-13
# 7       False  2010-04-12
# ...       ...         ...
# 2714    False  2006-01-05
# 2717     True  2006-01-04
# 2718    False  2006-01-03
# 2721    False  2006-01-02
# 2722    False  2006-01-01
#
# [1563 rows x 29 columns]

# %% [markdown]
# Do a first analysis of the remaining dataset, clean or drop data depending on how you see appropriate.

# %%
climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2724 entries, 0 to 2723
# Data columns (total 29 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   station_number                      2724 non-null   int64
#  1   wban_number                         2724 non-null   int64
#  2   mean_temp                           2724 non-null   float64
#  3   num_mean_temp_samples               2724 non-null   int64
#  4   mean_dew_point                      1563 non-null   float64
#  5   num_mean_dew_point_samples          1563 non-null   float64
#  6   mean_sealevel_pressure              1563 non-null   float64
#  7   num_mean_sealevel_pressure_samples  1563 non-null   float64
#  8   mean_station_pressure               65 non-null     float64
#  9   num_mean_station_pressure_samples   65 non-null     float64
#  10  mean_visibility                     1563 non-null   float64
#  11  num_mean_visibility_samples         1563 non-null   float64
#  12  mean_wind_speed                     2724 non-null   float64
#  13  num_mean_wind_speed_samples         2724 non-null   int64
#  14  max_sustained_wind_speed            2724 non-null   float64
#  15  max_gust_wind_speed                 1157 non-null   float64
#  16  max_temperature                     2724 non-null   float64
#  17  max_temperature_explicit            2724 non-null   bool
#  18  min_temperature                     0 non-null      float64
#  19  min_temperature_explicit            0 non-null      object
#  20  total_precipitation                 2717 non-null   float64
#  21  snow_depth                          289 non-null    float64
#  22  fog                                 2724 non-null   bool
#  23  rain                                2724 non-null   bool
#  24  snow                                2724 non-null   bool
#  25  hail                                2724 non-null   bool
#  26  thunder                             2724 non-null   bool
#  27  tornado                             2724 non-null   bool
#  28  date                                2724 non-null   object
# dtypes: bool(7), float64(16), int64(4), object(2)
# memory usage: 486.9+ KB

# %% [markdown]
# data cleansing and abstraction where appropriate, able to identifie columns that can be dropped, which information might be usefull and possible data imputation

# %% [markdown]
# ### 3. Task
# Now it is time to split the data, into a training, evaluation and test set. As a reminder, the date we are trying to predic snow fall for is the following, and hence should constitute your test set.

# %%
import datetime, timedelta

str(datetime.datetime.today()- datetime.timedelta(days=11*365)).split(' ')[0]
# Out:
# '2010-02-19'

# %% [markdown]
# ## Part 2
# If you made it up to here all by yourself, you can use your prepared dataset to train an Algorithm of your choice to forecast whether it will snow on the following date:

# %%
import datetime, timedelta

str(datetime.datetime.today()- datetime.timedelta(days=11*365)).split(' ')[0]
# Out:
# '2010-02-19'

# %% [markdown]
# You are allowed to use any library you are comfortable with such as sklearn, tensorflow keras etc.
# If you did not manage to finish part one feel free to use the data provided in 'coding_challenge.csv' Note that this data does not represent a solution to Part 1.
